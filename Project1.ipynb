# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_csv(r"C:\Users\Mohammed\Downloads\sales_data.csv")
df
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 2          1015  2023-09-21     David  South       4631.23             30
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 4          1061  2023-03-24   Charlie   East       3750.20             13
# ..          ...         ...       ...    ...           ...            ...
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
df.shape
# Out:
# (1000, 14)

# %%
df.drop_duplicates()
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 2          1015  2023-09-21     David  South       4631.23             30
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 4          1061  2023-03-24   Charlie   East       3750.20             13
# ..          ...         ...       ...    ...           ...            ...
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
df = df.drop(columns=['Region_and_Sales_Rep'])
df
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 2          1015  2023-09-21     David  South       4631.23             30
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 4          1061  2023-03-24   Charlie   East       3750.20             13
# ..          ...         ...       ...    ...           ...            ...
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_ID        1000 non-null   int64
#  1   Sale_Date         1000 non-null   object
#  2   Sales_Rep         1000 non-null   object
#  3   Region            1000 non-null   object
#  4   Sales_Amount      1000 non-null   float64
#  5   Quantity_Sold     1000 non-null   int64
#  6   Product_Category  1000 non-null   object
#  7   Unit_Cost         1000 non-null   float64
#  8   Unit_Price        1000 non-null   float64
#  9   Customer_Type     1000 non-null   object
#  10  Discount          1000 non-null   float64
#  11  Payment_Method    1000 non-null   object
#  12  Sales_Channel     1000 non-null   object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 101.7+ KB

# %%
df['Sale_Date'] = pd.to_datetime(df['Sale_Date'])
df
# Out:
#      Product_ID  Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052 2023-02-03       Bob  North       5053.97             18
# 1          1093 2023-04-21       Bob   West       4384.02             17
# 2          1015 2023-09-21     David  South       4631.23             30
# 3          1072 2023-08-24       Bob  South       2167.94             39
# 4          1061 2023-03-24   Charlie   East       3750.20             13
# ..          ...        ...       ...    ...           ...            ...
# 995        1010 2023-04-15   Charlie  North       4733.88              4
# 996        1067 2023-09-07       Bob  North       4716.36             37
# 997        1018 2023-04-27     David  South       7629.70             17
# 998        1100 2023-12-20     David   West       1629.47             39
# 999        1086 2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
df.dtypes
# Out:
# Product_ID                   int64
# Sale_Date           datetime64[ns]
# Sales_Rep                   object
# Region                      object
# Sales_Amount               float64
# Quantity_Sold                int64
# Product_Category            object
# Unit_Cost                  float64
# Unit_Price                 float64
# Customer_Type               object
# Discount                   float64
# Payment_Method              object
# Sales_Channel               object
# dtype: object

# %%
df
# Out:
#      Product_ID  Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052 2023-02-03       Bob  North       5053.97             18
# 1          1093 2023-04-21       Bob   West       4384.02             17
# 2          1015 2023-09-21     David  South       4631.23             30
# 3          1072 2023-08-24       Bob  South       2167.94             39
# 4          1061 2023-03-24   Charlie   East       3750.20             13
# ..          ...        ...       ...    ...           ...            ...
# 995        1010 2023-04-15   Charlie  North       4733.88              4
# 996        1067 2023-09-07       Bob  North       4716.36             37
# 997        1018 2023-04-27     David  South       7629.70             17
# 998        1100 2023-12-20     David   West       1629.47             39
# 999        1086 2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
df.sort_values(by='Sale_Date', ascending=True, inplace=True)
df
# Out:
#      Product_ID  Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 237        1070 2023-01-01       Eve  South        783.18             12
# 101        1089 2023-01-01   Charlie  North       8130.13             35
# 64         1008 2023-01-01       Eve  North       5227.81             38
# 363        1064 2023-01-02     David  South       5533.70             10
# 899        1075 2023-01-02     David   West        919.09             26
# ..          ...        ...       ...    ...           ...            ...
# 756        1090 2023-12-31       Eve   West       3333.73             46
# 523        1094 2023-12-31       Bob  South       6586.22             15
# 317        1018 2024-01-01     Alice   West       8579.72             24
# 873        1098 2024-01-01       Bob  South       2370.72             11
# 627        1078 2024-01-01     David   East       8377.57             42
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
df['Sales_Amount'].describe()
# Out:
# count    1000.000000
# mean     5019.265230
# std      2846.790126
# min       100.120000
# 25%      2550.297500
# 50%      5019.300000
# 75%      7507.445000
# max      9989.040000
# Name: Sales_Amount, dtype: float64

# %%
df['Sales_Amount'].median()
# Out:
# 5019.3

# %%
df['Quantity_Sold'].describe()
# Out:
# count    1000.000000
# mean       25.355000
# std        14.159006
# min         1.000000
# 25%        13.000000
# 50%        25.000000
# 75%        38.000000
# max        49.000000
# Name: Quantity_Sold, dtype: float64

# %%
df['Payment_Method'].describe()
# Out:
# count            1000
# unique              3
# top       Credit Card
# freq              345
# Name: Payment_Method, dtype: object

# %%
df[(df['Quantity_Sold'] > 13) & (df['Sales_Rep'] == 'Alice')]
# Out:
#      Product_ID  Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 858        1066 2023-01-09     Alice  North       6264.04             48
# 775        1013 2023-01-12     Alice   West       7646.80             35
# 80         1090 2023-01-13     Alice   East       2359.53             17
# 745        1012 2023-01-13     Alice   East       8892.37             39
# 130        1033 2023-01-14     Alice   West       1740.92             24
# ..          ...        ...       ...    ...           ...            ...
# 258        1003 2023-12-30     Alice   East        640.88             17
# 476        1058 2023-12-31     Alice   West       4643.51             44
# 173        1086 2023-12-31     Alice  South       9269.32             33
# 13         1003 2023-12-31     Alice  South       4775.59             30
# 317        1018 2024-01-01     Alice   West       8579.72             24
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
#what region sold more
sn.histplot(df['Region'])
# Out:
# <Axes: xlabel='Region', ylabel='Count'>

# %%
#what region sold more on average
region_avg_sales = df.groupby('Region')['Sales_Amount'].mean().reset_index()
print(region_avg_sales)

sn.barplot(region_avg_sales, x = 'Region', y = 'Sales_Amount')
# Out:
#   Region  Sales_Amount
# 0   East   4790.087186
# 1  North   5129.634869
# 2  South   5107.304690
# 3   West   5063.971025
# <Axes: xlabel='Region', ylabel='Sales_Amount'>

# %%
#what region sold more in total
sn.barplot(data=df, x = 'Region', y = 'Sales_Amount')
# Out:
# <Axes: xlabel='Region', ylabel='Sales_Amount'>

# %%
#who sold more
sn.barplot(df, x = 'Sales_Rep', y = 'Sales_Amount')
# Out:
# <Axes: xlabel='Sales_Rep', ylabel='Sales_Amount'>

# %%
#what product sold more
sn.barplot(df, x = 'Product_Category', y = 'Sales_Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Sales_Amount'>

# %%
#what type of customer purchased more(new or returning)
sn.barplot(df, x = 'Customer_Type', y = 'Sales_Amount')
# Out:
# <Axes: xlabel='Customer_Type', ylabel='Sales_Amount'>

# %%
#average quantity each products sell
sn.barplot(df, x = 'Product_Category', y = 'Quantity_Sold')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Quantity_Sold'>

# %%
df
# Out:
#      Product_ID  Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 237        1070 2023-01-01       Eve  South        783.18             12
# 101        1089 2023-01-01   Charlie  North       8130.13             35
# 64         1008 2023-01-01       Eve  North       5227.81             38
# 363        1064 2023-01-02     David  South       5533.70             10
# 899        1075 2023-01-02     David   West        919.09             26
# ..          ...        ...       ...    ...           ...            ...
# 756        1090 2023-12-31       Eve   West       3333.73             46
# 523        1094 2023-12-31       Bob  South       6586.22             15
# 317        1018 2024-01-01     Alice   West       8579.72             24
# 873        1098 2024-01-01       Bob  South       2370.72             11
# 627        1078 2024-01-01     David   East       8377.57             42
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
#average times Eve has passed a certain amount
sn.displot(df[df['Sales_Rep'] == 'Eve']['Sales_Amount'])

# %%
sn.violinplot(df, x = 'Region', y = 'Sales_Amount', hue = 'Sales_Rep')
# Out:
# <Axes: xlabel='Region', ylabel='Sales_Amount'>

# %%
sn.boxplot(df, x = 'Region', y = 'Sales_Amount', hue = 'Sales_Rep')
# Out:
# <Axes: xlabel='Region', ylabel='Sales_Amount'>

# %%
sn.pairplot(df[['Sales_Amount', 'Sales_Rep', 'Region']], hue = 'Region')

# %%
sn.lmplot(df, x = 'Sales_Amount', y = 'Quantity_Sold')

# %%
df.head(10)
# Out:
#      Product_ID  Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 237        1070 2023-01-01       Eve  South        783.18             12
# 101        1089 2023-01-01   Charlie  North       8130.13             35
# 64         1008 2023-01-01       Eve  North       5227.81             38
# 363        1064 2023-01-02     David  South       5533.70             10
# 899        1075 2023-01-02     David   West        919.09             26
# 940        1027 2023-01-03       Bob   East       7648.22             30
# 592        1099 2023-01-03       Bob   East       5613.10             31
# 652        1087 2023-01-03   Charlie   East       8057.76             20
# 560        1074 2023-01-04       Eve  South       7508.72             38
# 21         1064 2023-01-04       Eve   East       7412.11             10
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 237        Furniture     664.33      863.03     Returning      0.25
# ...
